# %% [markdown]
# # SQL Review, Extra
#
# This extra notebook contains a lot of extra SQL practice. Many variations of queries shown below are either in the slides or in course notes.

# %% [markdown]
# ## First load in the data into the database

# %%
# !unzip -u data/imdb_lecture.zip -d data/
# Out:
# Archive:  data/imdb_lecture.zip

# %%
# !psql -h localhost -c 'DROP DATABASE IF EXISTS imdb_lecture'
# !psql -h localhost -c 'CREATE DATABASE imdb_lecture' 
# !psql -h localhost -d imdb_lecture -f data/imdb_lecture.sql
# Out:
# DROP DATABASE
# CREATE DATABASE
# SET
# SET
# SET
# SET
# SET
#  set_config
# ------------
#
# (1 row)
#
# SET
# SET
# SET
# SET
# SET
# SET
# CREATE TABLE
# ALTER TABLE
# CREATE TABLE
# ALTER TABLE
# CREATE TABLE
# ALTER TABLE
# CREATE TABLE
# ALTER TABLE
# CREATE TABLE
# ALTER TABLE
# CREATE TABLE
# ALTER TABLE
# COPY 8405
# COPY 4043
# COPY 4923
# COPY 1223
# COPY 820
# COPY 2420

# %% [markdown]
# ## `jupysql` setup

# %%
# %reload_ext sql

# %%
# %sql postgresql://jovyan@127.0.0.1:5432/imdb_lecture
# Out:
# Connecting to 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'

# %% [markdown]
# ## CAST

# %% [markdown]
# What's wrong with the following query?

# %%
# %%sql
# SELECT primary_title, type,
#      premiered AS release_year,
#      runtime_minutes,
#      runtime_minutes/60 AS
#          runtime_hours
# FROM titles
# WHERE premiered >= 2020 AND
#       premiered <= 2023;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 115 rows affected.
# +-----------------------------------+----------+--------------+-----------------+---------------+
# |           primary_title           |   type   | release_year | runtime_minutes | runtime_hours |
# +-----------------------------------+----------+--------------+-----------------+---------------+
# |           Blood of Zeus           | tvSeries |     2020     |        30       |       0       |
# |           Gods & Heroes           | tvSeries |     2020     |        30       |       0       |
# |             Shaq Life             | tvSeries |     2020     |       None      |      None     |
# |            What's After           | tvSeries |     2020     |       None      |      None     |
# |               Utmark              | tvSeries |     2020     |       None      |      None     |
# |          La Femme Anjola          |  movie   |     2021     |       140       |       2       |
# |             Mr. Corman            | tvSeries |     2021     |       285       |       4       |
# | Player Vs Player with Trevor Noah | tvSeries |     2021     |       None      |      None     |
# |           Run for Young           | tvSeries |     2020     |       None      |      None     |
# |            Poker Nights           | tvSeries |     2021     |        6        |       0       |
# +-----------------------------------+----------+--------------+-----------------+---------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ## CASE statements

# %% [markdown]
# What's wrong with the following query?

# %%
# %%sql
# SELECT
#     person_id, name,
#     died, born,
#     died - born AS age
# FROM people;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 1223 rows affected.
# +------------+---------------------+------+------+------+
# | person_id  |         name        | died | born | age  |
# +------------+---------------------+------+------+------+
# | nm0384214  |     Dwayne Hill     | None | None | None |
# | nm0362443  |     Dave Hardman    | None | 1960 | None |
# | nm1560888  |   Rich Pryce-Jones  | None | None | None |
# | nm0006669  |    William Sadler   | None | 1950 | None |
# | nm1373094  | Giada De Laurentiis | None | 1970 | None |
# | nm7316782  |   Janine Hartmann   | None | None | None |
# | nm8671663  |   Tereza Taliánová  | None | 2005 | None |
# | nm10480297 |    Chris Heywood    | None | None | None |
# | nm10803545 |     Chengao Zhou    | None | None | None |
# | nm9849414  |     Mark Langley    | None | None | None |
# +------------+---------------------+------+------+------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ## Null values and boolean expressions

# %% [markdown]
# Compare/contrast the following three queries:

# %%
# %%sql
# SELECT born
# FROM people;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 1223 rows affected.
# +------+
# | born |
# +------+
# | None |
# | 1960 |
# | None |
# | 1950 |
# | 1970 |
# | None |
# | 2005 |
# | None |
# | None |
# | None |
# +------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT born
# FROM people
# WHERE born < 2023 OR
#     born IS NULL;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 1223 rows affected.
# +------+
# | born |
# +------+
# | None |
# | 1960 |
# | None |
# | 1950 |
# | 1970 |
# | None |
# | 2005 |
# | None |
# | None |
# | None |
# +------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT born
# FROM people
# WHERE born < 2023;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 577 rows affected.
# +------+
# | born |
# +------+
# | 1960 |
# | 1950 |
# | 1970 |
# | 2005 |
# | 1980 |
# | 1926 |
# | 1975 |
# | 1919 |
# | 1940 |
# | 1929 |
# +------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ## String matching and COUNT(*)

# %%
# %%sql
# SELECT *
# FROM people
# WHERE name LIKE 'Chris%';
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 84 rows affected.
# +------------+-----------------+------+------+
# | person_id  |       name      | born | died |
# +------------+-----------------+------+------+
# | nm10480297 |  Chris Heywood  | None | None |
# | nm9115948  |   Chris Bratt   | None | None |
# | nm6699360  |   Chris Evans   | None | None |
# | nm12363226 |  Chris Daniels  | None | None |
# | nm2653742  |   Chris Longo   | None | None |
# | nm5237685  |   Chris Evans   | None | None |
# | nm3074588  | Christian Bland | None | None |
# | nm5646425  |   Chris Evans   | None | None |
# | nm1470079  |  Chris Boiling  | None | None |
# | nm11632011 |   Chris Angold  | None | None |
# +------------+-----------------+------+------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ## Multiple relations, Aliasing

# %%
# %%sql
# SELECT *
# FROM
#     akas, titles
# WHERE
#     titles.title_id =
#         akas.title_id;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 8817 rows affected.
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# |  title_id  |           title           | region | language |    types    | attributes | is_original_title | title_id_1 |    type   |       primary_title       |       original_title      | is_adult | premiered | ended | runtime_minutes |      genres      |
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# | tt0909144  |             46            |   US   |   None   |     None    |    None    |         0         | tt0909144  | tvEpisode |             46            |             46            |    0     |    1971   |  None |       None      |  Comedy,Family   |
# | tt3719148  | Gustavo Lopez/Abel Pintos |   AR   |   None   |     None    |    None    |         0         | tt3719148  | tvEpisode | Gustavo Lopez/Abel Pintos | Gustavo Lopez/Abel Pintos |    0     |    2012   |  None |       None      | Comedy,Talk-Show |
# | tt9047618  |   The Women in the Sand   |   GB   |   None   | imdbDisplay |    None    |         0         | tt9047618  |   movie   |   The Women in the Sand   |   The Women in the Sand   |    0     |    2017   |  None |        73       |   Documentary    |
# | tt1259521  |    La cabaña del terror   |   AR   |   None   | imdbDisplay |    None    |         0         | tt1259521  |   movie   |   The Cabin in the Woods  |   The Cabin in the Woods  |    0     |    2011   |  None |        95       |      Horror      |
# | tt5557622  |         एपिसोड #1.15        |   IN   |    hi    |     None    |    None    |         0         | tt5557622  | tvEpisode |       Episode #1.15       |       Episode #1.15       |    0     |    2014   |  None |        59       |      Drama       |
# | tt10647574 |        Folge #1.106       |   DE   |    de    |     None    |    None    |         0         | tt10647574 | tvEpisode |       Episode #1.106      |       Episode #1.106      |    0     |    1953   |  None |       None      |      Drama       |
# | tt0111161  |     Побег из Шоушенка     |   RU   |   None   | imdbDisplay |    None    |         0         | tt0111161  |   movie   |  The Shawshank Redemption |  The Shawshank Redemption |    0     |    1994   |  None |       142       |      Drama       |
# | tt1642404  |      Episodio #1.4002     |   ES   |    es    |     None    |    None    |         0         | tt1642404  | tvEpisode |      Episode #1.4002      |      Episode #1.4002      |    0     |    2005   |  None |        28       |  Drama,Romance   |
# | tt0894015  |             28            |   US   |   None   |     None    |    None    |         0         | tt0894015  | tvEpisode |             28            |             28            |    0     |    1971   |  None |       None      |  Comedy,Family   |
# | tt10592866 |           Utmark          |   MX   |   None   | imdbDisplay |    None    |         0         | tt10592866 |  tvSeries |           Utmark          |           Utmark          |    0     |    2020   |  None |       None      |   Comedy,Drama   |
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT *
# FROM
#     akas AS A,
#     titles T
# WHERE
#     A.title_id = T.title_id;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 8817 rows affected.
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# |  title_id  |           title           | region | language |    types    | attributes | is_original_title | title_id_1 |    type   |       primary_title       |       original_title      | is_adult | premiered | ended | runtime_minutes |      genres      |
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# | tt0909144  |             46            |   US   |   None   |     None    |    None    |         0         | tt0909144  | tvEpisode |             46            |             46            |    0     |    1971   |  None |       None      |  Comedy,Family   |
# | tt3719148  | Gustavo Lopez/Abel Pintos |   AR   |   None   |     None    |    None    |         0         | tt3719148  | tvEpisode | Gustavo Lopez/Abel Pintos | Gustavo Lopez/Abel Pintos |    0     |    2012   |  None |       None      | Comedy,Talk-Show |
# | tt9047618  |   The Women in the Sand   |   GB   |   None   | imdbDisplay |    None    |         0         | tt9047618  |   movie   |   The Women in the Sand   |   The Women in the Sand   |    0     |    2017   |  None |        73       |   Documentary    |
# | tt1259521  |    La cabaña del terror   |   AR   |   None   | imdbDisplay |    None    |         0         | tt1259521  |   movie   |   The Cabin in the Woods  |   The Cabin in the Woods  |    0     |    2011   |  None |        95       |      Horror      |
# | tt5557622  |         एपिसोड #1.15        |   IN   |    hi    |     None    |    None    |         0         | tt5557622  | tvEpisode |       Episode #1.15       |       Episode #1.15       |    0     |    2014   |  None |        59       |      Drama       |
# | tt10647574 |        Folge #1.106       |   DE   |    de    |     None    |    None    |         0         | tt10647574 | tvEpisode |       Episode #1.106      |       Episode #1.106      |    0     |    1953   |  None |       None      |      Drama       |
# | tt0111161  |     Побег из Шоушенка     |   RU   |   None   | imdbDisplay |    None    |         0         | tt0111161  |   movie   |  The Shawshank Redemption |  The Shawshank Redemption |    0     |    1994   |  None |       142       |      Drama       |
# | tt1642404  |      Episodio #1.4002     |   ES   |    es    |     None    |    None    |         0         | tt1642404  | tvEpisode |      Episode #1.4002      |      Episode #1.4002      |    0     |    2005   |  None |        28       |  Drama,Romance   |
# | tt0894015  |             28            |   US   |   None   |     None    |    None    |         0         | tt0894015  | tvEpisode |             28            |             28            |    0     |    1971   |  None |       None      |  Comedy,Family   |
# | tt10592866 |           Utmark          |   MX   |   None   | imdbDisplay |    None    |         0         | tt10592866 |  tvSeries |           Utmark          |           Utmark          |    0     |    2020   |  None |       None      |   Comedy,Drama   |
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT *
# FROM akas A
#   INNER JOIN titles T
#     ON A.title_id = T.title_id
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 8817 rows affected.
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# |  title_id  |           title           | region | language |    types    | attributes | is_original_title | title_id_1 |    type   |       primary_title       |       original_title      | is_adult | premiered | ended | runtime_minutes |      genres      |
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# | tt0909144  |             46            |   US   |   None   |     None    |    None    |         0         | tt0909144  | tvEpisode |             46            |             46            |    0     |    1971   |  None |       None      |  Comedy,Family   |
# | tt3719148  | Gustavo Lopez/Abel Pintos |   AR   |   None   |     None    |    None    |         0         | tt3719148  | tvEpisode | Gustavo Lopez/Abel Pintos | Gustavo Lopez/Abel Pintos |    0     |    2012   |  None |       None      | Comedy,Talk-Show |
# | tt9047618  |   The Women in the Sand   |   GB   |   None   | imdbDisplay |    None    |         0         | tt9047618  |   movie   |   The Women in the Sand   |   The Women in the Sand   |    0     |    2017   |  None |        73       |   Documentary    |
# | tt1259521  |    La cabaña del terror   |   AR   |   None   | imdbDisplay |    None    |         0         | tt1259521  |   movie   |   The Cabin in the Woods  |   The Cabin in the Woods  |    0     |    2011   |  None |        95       |      Horror      |
# | tt5557622  |         एपिसोड #1.15        |   IN   |    hi    |     None    |    None    |         0         | tt5557622  | tvEpisode |       Episode #1.15       |       Episode #1.15       |    0     |    2014   |  None |        59       |      Drama       |
# | tt10647574 |        Folge #1.106       |   DE   |    de    |     None    |    None    |         0         | tt10647574 | tvEpisode |       Episode #1.106      |       Episode #1.106      |    0     |    1953   |  None |       None      |      Drama       |
# | tt0111161  |     Побег из Шоушенка     |   RU   |   None   | imdbDisplay |    None    |         0         | tt0111161  |   movie   |  The Shawshank Redemption |  The Shawshank Redemption |    0     |    1994   |  None |       142       |      Drama       |
# | tt1642404  |      Episodio #1.4002     |   ES   |    es    |     None    |    None    |         0         | tt1642404  | tvEpisode |      Episode #1.4002      |      Episode #1.4002      |    0     |    2005   |  None |        28       |  Drama,Romance   |
# | tt0894015  |             28            |   US   |   None   |     None    |    None    |         0         | tt0894015  | tvEpisode |             28            |             28            |    0     |    1971   |  None |       None      |  Comedy,Family   |
# | tt10592866 |           Utmark          |   MX   |   None   | imdbDisplay |    None    |         0         | tt10592866 |  tvSeries |           Utmark          |           Utmark          |    0     |    2020   |  None |       None      |   Comedy,Drama   |
# +------------+---------------------------+--------+----------+-------------+------------+-------------------+------------+-----------+---------------------------+---------------------------+----------+-----------+-------+-----------------+------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# # IMDB exercise 1

# %% [markdown]
# What does each record represent in the below result? Why?

# %%
# %%sql
# SELECT *
# FROM titles
#
#   INNER JOIN crew
#     ON crew.title_id =
#        titles.title_id
#
#
#   INNER JOIN people
# 	 ON people.person_id =
#        crew.person_id;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 3171 rows affected.
# +-----------+-------+------------------------------+-----------------------------+----------+-----------+-------+-----------------+-------------+------------+-----------+----------+------+-------------+-----------------------+------+------+
# |  title_id |  type |        primary_title         |        original_title       | is_adult | premiered | ended | runtime_minutes |    genres   | title_id_1 | person_id | category | job  | person_id_1 |          name         | born | died |
# +-----------+-------+------------------------------+-----------------------------+----------+-----------+-------+-----------------+-------------+------------+-----------+----------+------+-------------+-----------------------+------+------+
# | tt0008572 | movie |      The Silent Master       |      The Silent Master      |    0     |    1917   |  None |       None      | Crime,Drama | tt0008572  | nm0913094 |  actor   | None |  nm0913094  |     Robert Warwick    | 1878 | 1964 |
# | tt0008572 | movie |      The Silent Master       |      The Silent Master      |    0     |    1917   |  None |        70       | Crime,Drama | tt0008572  | nm0913094 |  actor   | None |  nm0913094  |     Robert Warwick    | 1878 | 1964 |
# | tt0009202 | movie |      The House of Glass      |      The House of Glass     |    0     |    1918   |  None |        50       |    Drama    | tt0009202  | nm0154352 | director | None |  nm0154352  |     Emile Chautard    | 1864 | 1934 |
# | tt0009202 | movie |      The House of Glass      |      The House of Glass     |    0     |    1918   |  None |        50       |    Drama    | tt0009202  | nm0453799 |  actor   | None |  nm0453799  |     Edward Kimball    | 1859 | 1938 |
# | tt0009202 | movie |      The House of Glass      |      The House of Glass     |    0     |    1918   |  None |        50       |    Drama    | tt0009202  | nm0545730 |  writer  | play |  nm0545730  |       Max Marcin      | 1879 | 1948 |
# | tt0009202 | movie |      The House of Glass      |      The House of Glass     |    0     |    1918   |  None |        50       |    Drama    | tt0009202  | nm0872200 |  actor   | None |  nm0872200  |      Pell Trenton     | 1883 | 1924 |
# | tt0015483 | movie |    What Three Men Wanted     |    What Three Men Wanted    |    0     |    1924   |  None |       None      |   Mystery   | tt0015483  | nm0122829 | director | None |  nm0122829  |       Paul Burns      | 1891 | 1978 |
# | tt0015483 | movie |    What Three Men Wanted     |    What Three Men Wanted    |    0     |    1924   |  None |       None      |   Mystery   | tt0015483  | nm0243323 | actress  | None |  nm0243323  |      Miss DuPont      | 1894 | 1973 |
# | tt0015483 | movie |    What Three Men Wanted     |    What Three Men Wanted    |    0     |    1924   |  None |       None      |   Mystery   | tt0015483  | nm0496470 |  actor   | None |  nm0496470  |      Otto Lederer     | 1886 | 1965 |
# | tt0017099 | movie | Madame Doesn't Want Children | Madame wünscht keine Kinder |    0     |    1926   |  None |        98       |    Drama    | tt0017099  | nm0006278 | composer | None |  nm0006278  | Willy Schmidt-Gentner | 1894 | 1964 |
# +-----------+-------+------------------------------+-----------------------------+----------+-----------+-------+-----------------+-------------+------------+-----------+----------+------+-------------+-----------------------+------+------+
# Truncated to displaylimit of 10.

# %% [markdown]
# How do we modify the above query so that it gets the
# titles and IDs of Michelle Yeoh movies?

# %% [markdown]
# # IMDB exercise 2

# %% [markdown]
# How do we write a query that gets the names of Michelle Yeoh movies
# that have a rating of at least 8.0?

# %% [markdown]
# First, let's create a view called `yeoh_movies`.

# %%
# %%sql
# CREATE VIEW yeoh_movies AS (
#   -- fill query here
# );
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (psycopg2.errors.SyntaxError) syntax error at or near ")"
# LINE 3: );
#         ^
#
# [SQL: CREATE VIEW yeoh_movies AS (
#
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# SELECT * FROM yeoh_movies;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (psycopg2.errors.UndefinedTable) relation "yeoh_movies" does not exist
# LINE 1: SELECT * FROM yeoh_movies;
#                       ^
#
# [SQL: SELECT * FROM yeoh_movies;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# SELECT primary_title
# FROM ratings
# INNER JOIN yeoh_movies
#   ON ratings.title_id = yeoh_movies.title_id
# WHERE rating >= 7.0;

# %% [markdown]
# ## Quick Peek: The Natural Join

# %%
# %%sql
# SELECT *
# FROM ratings
# INNER JOIN yeoh_movies
#   ON ratings.title_id =
#    yeoh_movies.title_id
# WHERE rating >= 7.0;

# %%
# %%sql
# SELECT *
# FROM ratings
# NATURAL JOIN yeoh_movies
# WHERE rating >= 7.0;

# %%
# %%sql
# SELECT DISTINCT titles.primary_title, titles.title_id
# FROM titles
#     INNER JOIN crew
#         ON crew.title_id = titles.title_id
#     INNER JOIN people
#         ON people.person_id = crew.person_id
# WHERE people.name = 'Morgan Freeman' AND titles.type = 'movie';

# %% [markdown]
# # Tricky Queries

# %% [markdown]
# What do these queries do?

# %%
# %%sql
# SELECT REGEXP_REPLACE(name, '(.*) (.*)', '\1')
#          as firstname,
#        COUNT(*) as countname
# FROM people
# GROUP BY firstname
# ORDER BY countname DESC;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 871 rows affected.
# +-----------+-----------+
# | firstname | countname |
# +-----------+-----------+
# |   Chris   |     79    |
# |   David   |     18    |
# |  Michael  |     16    |
# |   Steve   |     10    |
# |   Peter   |     9     |
# |    John   |     9     |
# |    Tom    |     8     |
# |    Mark   |     8     |
# |    Dan    |     8     |
# |    Paul   |     6     |
# +-----------+-----------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT type,
# AVG (CASE WHEN premiered < 2000 THEN runtime_minutes
#      ELSE NULL
#      END) AS pre2k_avg, AVG (CASE WHEN premiered >= 2000 THEN runtime_minutes
#      ELSE NULL
#      END) AS post2k_avg
# FROM titles
# GROUP BY type;
# Out:
# Running query in 'postgresql://jovyan@127.0.0.1:5432/imdb_lecture'
# 10 rows affected.
# +--------------+----------------------+---------------------+
# |     type     |      pre2k_avg       |      post2k_avg     |
# +--------------+----------------------+---------------------+
# |   tvShort    |         None         |  7.0000000000000000 |
# |    movie     | 90.4646464646464646  | 95.2086330935251799 |
# |    short     | 23.0000000000000000  | 12.3333333333333333 |
# |   tvMovie    | 86.6000000000000000  | 75.3636363636363636 |
# | tvMiniSeries | 445.0000000000000000 | 46.0000000000000000 |
# |  videoGame   |         None         |         None        |
# |  tvEpisode   | 33.7555555555555556  | 39.1797752808988764 |
# |    video     | 41.4285714285714286  | 33.6829268292682927 |
# |  tvSpecial   |         None         | 76.3333333333333333 |
# |   tvSeries   | 65.7142857142857143  | 52.3055555555555556 |
# +--------------+----------------------+---------------------+
# Truncated to displaylimit of 10.
# Closing postgresql://jovyan@127.0.0.1:5432/imdb_lecture
